# %% [markdown]
# # Week 2 Project

# %% [markdown]
# Once again, we’ll be using the [Women's Ecommerce Clothing Reviews Dataset from Kaggle](https://www.kaggle.com/datasets/nicapotato/womens-ecommerce-clothing-reviews), which Kaggle states is a
#
# > dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.
#
# The machine learning task will be sentiment analysis, classifying each review as having positive or negative sentiment.

# %% [markdown]
# ## Task 1: Training and Evaluating Sentiment Analysis Models Using Metaflow
#
# In this task, you'll use Metaflow to build two machine learning models for sentiment analysis: a baseline *"majority class"* classifier and your own custom model. You'll then train both models in parallel and experiment with different hyperparameters to optimize their performance. Finally, you'll use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Here's what you'll need to do:
#
# ### Step 1: Build the Workflows
# The first step in this task is to build the workflow(s) for sentiment analysis using the Metaflow framework. Start by creating a new flow in Metaflow and implementing the baseline *"majority class"* classifier. Then, build your own custom classifier using techniques you learned in Week 1, or any [helpful resources](https://outerbounds.com/docs/nlp-tutorial-L2/) you'd like. For your custom model, be sure to include steps for data preprocessing, model training, and evaluation.
#
# ### Step 2: Train Both Models in Parallel
# Once you've built your models, the next step is to train both models in parallel using the Metaflow framework. Use Metaflow to run both training jobs in parallel steps. If you get stuck, you may want to review the [FlowSpec branching documentation](https://docs.metaflow.org/metaflow/basics#branch).
#
# ### Step 3: Experiment with Hyperparameters
# After you've trained both models in parallel, the next step is to experiment with different hyperparameters to optimize their performance. Try different values for hyperparameters such as learning rate, batch size, and number of epochs, and record the results for each combination of hyperparameters as Data Artifacts in Metaflow.
#
# ### Step 4: Analyze the Results
# Finally, use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Create visualizations to compare the performance of the two models and identify the best hyperparameters for each one.
#
# By completing this task, you'll gain experience working with the Metaflow framework and learn how to build and optimize machine learning workflows for sentiment analysis.

# %%
from collections import Counter
import pandas as pd
import numpy as np 
from termcolor import colored
import matplotlib.pyplot as plt
import seaborn as sns
import string
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.dummy import DummyClassifier

# You can style your plots here, but it is not part of the project.
YELLOW = '#FFBC00'
GREEN = '#37795D'
PURPLE = '#5460C0'
BACKGROUND = '#F4EBE6'
colors = [GREEN, PURPLE]
custom_params = {
    'axes.spines.right': False, 'axes.spines.top': False,
    'axes.facecolor':BACKGROUND, 'figure.facecolor': BACKGROUND, 
    'figure.figsize':(8, 8)
}
sns_palette = sns.color_palette(colors, len(colors))
sns.set_theme(style='ticks', rc=custom_params)

# %%
# TODO: load the data. 
df = pd.read_csv("../data/Womens Clothing E-Commerce Reviews.csv", index_col=0)
labeling_function = lambda row: 1 if row["rating"] > 3 else 0
# transformations
df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
df = df[~df.review_text.isna()]
df['review'] = df['review_text'].astype('str')
_has_review_df = df[df['review_text'] != 'nan']
reviews = _has_review_df['review_text']
labels = _has_review_df.apply(labeling_function, axis=1)
df = pd.DataFrame({'label': labels, **_has_review_df})

# split into training and validation.
_df = pd.DataFrame({'review': reviews, 'label': labels})
traindf, valdf = train_test_split(_df, test_size=0.2)

# %%
# TODO: build the majority class baseline model. 
majority_clf = DummyClassifier(strategy="most_frequent")
majority_clf.fit(traindf["review"], traindf["label"])

# TODO: find the majority class in the labels. 🤔
majority_preds = majority_clf.predict(valdf["review"])

# TODO: score the model on valdf with a 2D metric space: sklearn.metrics.accuracy_score, sklearn.metrics.roc_auc_score
    # Documentation on suggested model-scoring approach: https://scikit-learn.org/stable/modules/model_evaluation.html
majority_acc = accuracy_score(valdf["label"], majority_preds)
majority_roc = roc_auc_score(valdf["label"], majority_preds)
print(f"majority_acc: {majority_acc}")
print(f"majority_roc: {majority_roc}")
# Out:
# majority_acc: 0.774122322808567
# majority_roc: 0.5

# %%
# %%writefile model_01.py
# TODO: modify this custom model to your liking. Check out this tutorial for more on this class: https://outerbounds.com/docs/nlp-tutorial-L2/
# TODO: train the model on traindf.
# TODO: score the model on valdf with _the same_ 2D metric space you used in previous cell.
# TODO: test your model works by importing the model module in notebook cells, and trying to fit traindf and score predictions on the valdf data!

import tensorflow as tf
from tensorflow.keras import layers, optimizers, regularizers
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.feature_extraction.text import CountVectorizer

class NbowModel():
    def __init__(self, vocab_sz, epochs, batch_size):
        self.vocab_sz = vocab_sz
        self.epochs = epochs
        self.batch_size = batch_size

        # Instantiate the CountVectorizer
        self.cv = CountVectorizer(
            min_df=.005, max_df = .75, stop_words='english', 
            strip_accents='ascii', max_features=self.vocab_sz
        )

        # Define the keras model
        inputs = tf.keras.Input(shape=(self.vocab_sz,), 
                                name='input')
        x = layers.Dropout(0.10)(inputs)
        x = layers.Dense(
            15, activation="relu",
            kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
        )(x)
        predictions = layers.Dense(1, activation="sigmoid",)(x)
        self.model = tf.keras.Model(inputs, predictions)
        opt = optimizers.Adam(learning_rate=0.002)
        self.model.compile(loss="binary_crossentropy", 
                           optimizer=opt, metrics=["accuracy"])
        print(f"vocab_sz: {self.vocab_sz}")
        print(f"epochs: {self.epochs}")
        print(f"batch_size: {self.batch_size}")

    def fit(self, X, y):
        print(X.shape)
        print(X[0])
        res = self.cv.fit_transform(X).toarray()
        self.model.fit(x=res, y=y, batch_size=self.batch_size, 
                       epochs=self.epochs, validation_split=.2)
    
    def predict(self, X):
        print(X.shape)
        print(X[0])
        res = self.cv.transform(X).toarray()
        return self.model.predict(res)
    
    def eval_acc(self, X, labels, threshold=.5):
        return accuracy_score(labels, 
                              self.predict(X) > threshold)
    
    def eval_rocauc(self, X, labels):
        return roc_auc_score(labels,  self.predict(X))

    @property
    def model_dict(self): 
        return {'vectorizer':self.cv, 'model': self.model, "epochs": self.epochs, "batch_size": self.batch_size}

    @classmethod
    def from_dict(cls, model_dict):
        "Get Model from dictionary"
        print(model_dict)
        nbow_model = cls(len(
            model_dict['vectorizer'].vocabulary_
        ), model_dict["epochs"], model_dict["batch_size"])
        nbow_model.epochs = model_dict["epochs"]
        nbow_model.cv = model_dict['vectorizer']
        return nbow_model
# Out:
# Writing model_01.py

# %%
# Training model
from model_01 import NbowModel
model = NbowModel(500, 20, 32)
model.fit(traindf["review"], traindf["label"])
# Out:
# ** here
# vocab_sz: 500
# epochs: 20
# batch_size: 32
# (18112,)
# Absolutely wonderful - silky and sexy and comfortable
# Epoch 1/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4383 - accuracy: 0.8025 - val_loss: 0.3297 - val_accuracy: 0.8592
# Epoch 2/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3362 - accuracy: 0.8573 - val_loss: 0.3230 - val_accuracy: 0.8628
# Epoch 3/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.3192 - accuracy: 0.8663 - val_loss: 0.3241 - val_accuracy: 0.8614
# Epoch 4/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.3109 - accuracy: 0.8690 - val_loss: 0.3263 - val_accuracy: 0.8584
# Epoch 5/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.3106 - accuracy: 0.8706 - val_loss: 0.3317 - val_accuracy: 0.8570
# Epoch 6/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.3006 - accuracy: 0.8754 - val_loss: 0.3367 - val_accuracy: 0.8543
# Epoch 7/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2887 - accuracy: 0.8871 - val_loss: 0.3343 - val_accuracy: 0.8598
# Epoch 8/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2841 - accuracy: 0.8850 - val_loss: 0.3426 - val_accuracy: 0.8570
# Epoch 9/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2766 - accuracy: 0.8910 - val_loss: 0.3521 - val_accuracy: 0.8556
# Epoch 10/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2722 - accuracy: 0.8954 - val_loss: 0.3566 - val_accuracy: 0.8523
# Epoch 11/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2646 - accuracy: 0.9007 - val_loss: 0.3624 - val_accuracy: 0.8493
# Epoch 12/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2526 - accuracy: 0.9079 - val_loss: 0.3659 - val_accuracy: 0.8476
# Epoch 13/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2486 - accuracy: 0.9062 - val_loss: 0.3812 - val_accuracy: 0.8429
# Epoch 14/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2434 - accuracy: 0.9156 - val_loss: 0.3852 - val_accuracy: 0.8446
# Epoch 15/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2376 - accuracy: 0.9185 - val_loss: 0.3981 - val_accuracy: 0.8391
# Epoch 16/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2340 - accuracy: 0.9173 - val_loss: 0.4052 - val_accuracy: 0.8474
# Epoch 17/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2280 - accuracy: 0.9209 - val_loss: 0.4049 - val_accuracy: 0.8424
# Epoch 18/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2217 - accuracy: 0.9259 - val_loss: 0.4204 - val_accuracy: 0.8416
# Epoch 19/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2143 - accuracy: 0.9227 - val_loss: 0.4254 - val_accuracy: 0.8424
# Epoch 20/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2186 - accuracy: 0.9276 - val_loss: 0.4363 - val_accuracy: 0.8407

# %%
# %%writefile baseline_challenge.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass

labeling_function = labeling_function = lambda row: 1 if row["rating"] > 3 else 0  # TODO: Define your labeling function here.

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')

    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = ... 
        # TODO: load the data. 
        df = pd.read_csv(io.StringIO(self.data), index_col=0)
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files


        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        from sklearn.metrics import accuracy_score, roc_auc_score
        from sklearn.dummy import DummyClassifier
        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        majority_clf = DummyClassifier(strategy="most_frequent")
        majority_clf.fit(self.traindf["review"], self.traindf["label"])
    
        predictions = majority_clf.predict(self.valdf["review"]) # TODO: predict the majority class
        acc = accuracy_score(self.valdf["label"], predictions) # TODO: return the accuracy_score of these predictions
         
        rocauc = roc_auc_score(self.valdf["label"], predictions) # TODO: return the roc_auc_score of these predictions
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):
        # TODO: import your model if it is defined in another file.
        from model_01 import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100, "epochs": 20, "batch_size": 32}, {'vocab_sz': 300, "epochs": 20, "batch_size": 32}, {'vocab_sz': 500, "epochs": 20, "batch_size": 32}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(params["vocab_sz"], params["epochs"], params["batch_size"]) # TODO: instantiate your custom model here!
            model.fit(X=self.df['review'], y=self.df['label'])

            acc = model.eval_acc(self.valdf["review"].values, self.valdf["label"]) # TODO: evaluate your custom model in an equivalent way to accuracy_score.
            rocauc = model.eval_rocauc(self.valdf["review"].values, self.valdf["label"]) # TODO: evaluate your custom model in an equivalent way to roc_auc_score.
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))

        self.next(self.aggregate)

    @step
    def aggregate(self, inputs):
        # No operation here for now.
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Overwriting baseline_challenge.py

# %%
! python baseline_challenge.py run --data "../data/Womens Clothing E-Commerce Reviews.csv"
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file ../data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-07 16:26:54.858 Workflow starting (run-id 30), see it in the UI at https://ui-pw-1998985377.outerbounds.dev/BaselineChallenge/30
# 2023-05-07 16:26:55.054 [30/start/157 (pid 28329)] Task is starting.
# 2023-05-07 16:26:57.993 [30/start/157 (pid 28329)] num of rows in train set: 18112
# 2023-05-07 16:27:00.741 [30/start/157 (pid 28329)] num of rows in validation set: 4529
# 2023-05-07 16:27:00.962 [30/start/157 (pid 28329)] Task finished successfully.
# 2023-05-07 16:27:01.328 [30/baseline/158 (pid 28434)] Task is starting.
# 2023-05-07 16:27:01.490 [30/model/159 (pid 28437)] Task is starting.
# 2023-05-07 16:27:05.888 [30/model/159 (pid 28437)] ** here
# 2023-05-07 16:27:05.899 [30/model/159 (pid 28437)] 2023-05-07 16:27:05.899037: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-07 16:27:05.918 [30/model/159 (pid 28437)] vocab_sz: 100
# 2023-05-07 16:27:06.160 [30/model/159 (pid 28437)] epochs: 20
# 2023-05-07 16:27:06.161 [30/model/159 (pid 28437)] batch_size: 32
# 2023-05-07 16:27:06.161 [30/model/159 (pid 28437)] (22641,)
# 2023-05-07 16:27:06.161 [30/model/159 (pid 28437)] Absolutely wonderful - silky and sexy and comfortable
# 2023-05-07 16:27:07.214 [30/baseline/158 (pid 28434)] Task finished successfully.
# 2023-05-07 16:27:07.359 [30/model/159 (pid 28437)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-07 16:27:07.359 [30/model/159 (pid 28437)] Epoch 1/20
# 2023-05-07 16:27:07.359 [30/model/159 (pid 28437)] 2023-05-07 16:27:07.037623: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 566/566 [==============================] - 1s 2ms/step - loss: 0.
# 2023-05-07 16:27:37.575 [30/model/159 (pid 28437)] Epoch 16/20
# 566/566 [==============================] - 1s 934us/step - loss: 0.2338 - accuracy: 0.9157 - val_loss: 0.4030 - val_accuracy: 0.84994 - accuracy: 0.93
# 2023-05-07 16:27:38.105 [30/model/159 (pid 28437)] Epoch 17/20
# 566/566 [==============================] - 1s 925us/step - loss: 0.2313 - accuracy: 0.9209 - val_loss: 0.4051 - val_accuracy: 0.85017 - accuracy: 0.93
# 2023-05-07 16:27:38.629 [30/model/159 (pid 28437)] Epoch 18/20
# 566/566 [==============================] - 1s 932us/step - loss: 0.2239 - accuracy: 0.9217 - val_loss: 0.4178 - val_accuracy: 0.84769 - accuracy: 0.87
# 2023-05-07 16:27:39.157 [30/model/159 (pid 28437)] Epoch 19/20
# 566/566 [==============================] - 1s 936us/step - loss: 0.2262 - accuracy: 0.9218 - val_loss: 0.4317 - val_accuracy: 0.84763 - accuracy: 0.90
# 2023-05-07 16:27:39.688 [30/model/159 (pid 28437)] Epoch 20/20
# 566/566 [==============================] - 1s 937us/step - loss: 0.2233 - accuracy: 0.9219 - val_loss: 0.4300 - val_accuracy: 0.84521 - accuracy: 0.90
# 2023-05-07 16:27:40.227 [30/model/159 (pid 28437)] (4529,)
# 2023-05-07 16:27:40.513 [30/model/159 (pid 28437)] Probably should have noticed the material this jumpsuit is made of before buying. tencel, thus little to no give,kind of like linen and silk. beautiful material, soft with a slight sheen. the top portion fits well and the triangles cover the girls well (36dd). unfortunately there is no give on the back end for my bottom which is quite round and its tight around my thighs which aren't small either. (l/xl and 14). and sadly an xl would be too big upstairs and baggy around the middle. sigh, oh well
# 2023-05-07 16:27:40.513 [30/model/159 (pid 28437)] (4529,)
# 2023-05-07 16:27:43.436 [30/model/159 (pid 28437)] 2023-05-07 16:27:07.055284: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# 2023-05-07 16:27:43.436 [30/model/159 (pid 28437)] Probably should have noticed the material this jumpsuit is made of before buying. tencel, thus little to no give,kind of like linen and silk. beautiful material, soft with a slight sheen. the top portion fits well and the triangles cover the girls well (36dd). unfortunately there is no give on the back end for my bottom which is quite round and its tight around my thighs which aren't small either. (l/xl and 14). and sadly an xl would be too big upstairs and baggy around the middle. sigh, oh well
# 2023-05-07 16:27:43.684 [30/model/159 (pid 28437)] Task finished successfully.
# 2023-05-07 16:27:44.056 [30/aggregate/160 (pid 28858)] Task is starting.
# 2023-05-07 16:27:46.950 [30/aggregate/160 (pid 28858)] Task finished successfully.
# 2023-05-07 16:27:47.221 [30/end/161 (pid 28919)] Task is starting.
# 2023-05-07 16:27:49.741 [30/end/161 (pid 28919)] Task finished successfully.
# 2023-05-07 16:27:49.862 Done! See the run in the UI at https://ui-pw-1998985377.outerbounds.dev/BaselineChallenge/30

# %% [markdown]
# ## Task 2: Anticipating Failure in Your Machine Learning Project
#
# In this task, you'll practice anticipating potential failure modes in a sentiment analysis classifier and develop strategies to mitigate them. Here's what you'll need to do:
# ### Step 1: Identify Potential Failure Modes
#
# The first step in anticipating failure in your machine learning project is to identify potential failure modes. Start by brainstorming ways in which your project could fail from an engineering point of view. For example, your model could overfit to the training data or suffer from data bias.
# ### Step 2: Develop Strategies to Mitigate Failure Modes
#
# Once you've identified potential failure modes, the next step is to develop strategies to mitigate them. Think about what measures you could take to fix the issue if it were to occur. For example, if your model is overfitting to the training data, you could try regularization techniques such as L1 or L2 regularization to reduce the complexity of the model.
# ### Step 3: Plan Ahead to Avoid Failure Modes
#
# Finally, it's important to plan ahead to avoid potential failure modes in the first place. Think about what you could have done initially to avoid these failure modes. For example, you could have collected a diverse set of training data to reduce data bias or experimented with different model architectures to find the best solution for your problem.
#
# The key to anticipating failure in your machine learning project is to be proactive rather than reactive. By identifying potential failure modes ahead of time and developing strategies to mitigate them, you'll be better equipped to build a successful machine learning project.

# %% [markdown]
# ## Task 3: Visualizing ML Results with MF Cards
# Now it is time to iterate. Extend the flow in your `baseline_challenge.py` file to include a step that aggregates all of the results from hyperparameter tuning jobs, and logs results and a data visualiation in a Metaflow card.

# %%
# %%writefile baseline_challenge_ext.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass

labeling_function = labeling_function = labeling_function = lambda row: 1 if row["rating"] > 3 else 0  # TODO: Define your labeling function here. # TODO: Define your labeling function here.

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge_01(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')

    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        df = ... 
        # TODO: load the data. 
        df = pd.read_csv(io.StringIO(self.data), index_col=0)
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files


        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline"

        from sklearn.metrics import accuracy_score, roc_auc_score
        from sklearn.dummy import DummyClassifier
        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        majority_clf = DummyClassifier(strategy="most_frequent")
        majority_clf.fit(self.traindf["review"], self.traindf["label"])
    
        predictions = majority_clf.predict(self.valdf["review"]) # TODO: predict the majority class
        acc = accuracy_score(self.valdf["label"], predictions) # TODO: return the accuracy_score of these predictions
         
        rocauc = roc_auc_score(self.valdf["label"], predictions) # TODO: return the roc_auc_score of these predictions
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):
        # TODO: import your model if it is defined in another file.
        from model_01 import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100, "epochs": 20, "batch_size": 32}, {'vocab_sz': 300, "epochs": 20, "batch_size": 32}, {'vocab_sz': 500, "epochs": 20, "batch_size": 32}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(params["vocab_sz"], params["epochs"], params["batch_size"]) # TODO: instantiate your custom model here!
            model.fit(X=self.df['review'], y=self.df['label'])

            acc = model.eval_acc(self.valdf["review"].values, self.valdf["label"]) # TODO: evaluate your custom model in an equivalent way to accuracy_score.
            rocauc = model.eval_rocauc(self.valdf["review"].values, self.valdf["label"]) # TODO: evaluate your custom model in an equivalent way to roc_auc_score.
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))

        self.next(self.aggregate)

    def add_one(self, rows, result, df):
        "A helper function to load results."
        rows.append([
            Markdown(result.name),
            Artifact(result.params),
            Artifact(result.pathspec),
            Artifact(result.acc),
            Artifact(result.rocauc)
        ])
        df['name'].append(result.name)
        df['accuracy'].append(result.acc)
        return rows, df

    @card(type="corise")
    @step
    def aggregate(self, inputs):

        import seaborn as sns
        import matplotlib.pyplot as plt
        from matplotlib import rcParams 
        rcParams.update({'figure.autolayout': True})

        rows = []
        violin_plot_df = {'name': [], 'accuracy': []}
        for task in inputs:
            if task._name == "model": 
                for result in task.results:
                    print(result)
                    rows, violin_plot_df = self.add_one(rows, result, violin_plot_df)
            elif task._name == "baseline":
                print(task.result)
                rows, violin_plot_df = self.add_one(rows, task.result, violin_plot_df)
            else:
                raise ValueError("Unknown task._name type. Cannot parse results.")
            
        current.card.append(Markdown("# All models from this flow run"))

        # TODO: Add a Table of the results to your card! 
        current.card.append(
            Table(rows, # TODO: What goes here to populate the Table in the card? 
                headers=["Model name", "Params", "Task pathspec", "Accuracy", "ROCAUC"]
            )
        )
        
        fig, ax = plt.subplots(1,1)
        plt.xticks(rotation=40)
        sns.violinplot(data=violin_plot_df, x="name", y="accuracy", ax=ax)
        
        # TODO: Append the matplotlib fig to the card
        # Docs: https://docs.metaflow.org/metaflow/visualizing-results/easy-custom-reports-with-card-components#showing-plots
        current.card.append(Image.from_matplotlib(fig))
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge_01()
# Out:
# Overwriting baseline_challenge_ext.py

# %%
! python baseline_challenge_ext.py run --data "../data/Womens Clothing E-Commerce Reviews.csv"
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge_01 for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file ../data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-07 17:08:34.527 Workflow starting (run-id 34), see it in the UI at https://ui-pw-1998985377.outerbounds.dev/BaselineChallenge_01/34
# 2023-05-07 17:08:34.734 [34/start/181 (pid 31475)] Task is starting.
# 2023-05-07 17:08:37.713 [34/start/181 (pid 31475)] num of rows in train set: 18112
# 2023-05-07 17:08:40.636 [34/start/181 (pid 31475)] num of rows in validation set: 4529
# 2023-05-07 17:08:40.818 [34/start/181 (pid 31475)] Task finished successfully.
# 2023-05-07 17:08:41.148 [34/baseline/182 (pid 31590)] Task is starting.
# 2023-05-07 17:08:41.291 [34/model/183 (pid 31593)] Task is starting.
# 2023-05-07 17:08:45.735 [34/model/183 (pid 31593)] ** here
# 2023-05-07 17:08:45.746 [34/model/183 (pid 31593)] 2023-05-07 17:08:45.746316: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-07 17:08:45.766 [34/model/183 (pid 31593)] vocab_sz: 100
# 2023-05-07 17:08:45.935 [34/model/183 (pid 31593)] epochs: 20
# 2023-05-07 17:08:45.935 [34/model/183 (pid 31593)] batch_size: 32
# 2023-05-07 17:08:45.935 [34/model/183 (pid 31593)] (22641,)
# 2023-05-07 17:08:45.935 [34/model/183 (pid 31593)] Absolutely wonderful - silky and sexy and comfortable
# 2023-05-07 17:08:46.705 [34/baseline/182 (pid 31590)] Task finished successfully.
# 2023-05-07 17:08:46.876 [34/model/183 (pid 31593)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-07 17:08:46.876 [34/model/183 (pid 31593)] Epoch 1/20
# 2023-05-07 17:08:46.876 [34/model/183 (pid 31593)] 2023-05-07 17:08:46.788585: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 566/566 [==============================] - 1s 2ms/step - loss: 0.4906 - accuracy: 0.7763 - val_loss: 0.4149 - val_accuracy: 0.8143.6592 - accuracy: 0.68
# 2023-05-07 17:08:48.023 [34/model/183 (pid 31593)] Epoch 2/20
# 566/566 [==============================] - 0s 767us/step - loss: 0.4212 - accuracy: 0.8099 - val_loss: 0.4131 - val_accuracy: 0.81412 - accuracy: 1.00
# 2023-05-07 17:08:48.458 [34/model/183 (pid 31593)] Epoch 3/20
# 566/566 [==============================] - 0s 779us/step - loss: 0.4179 - accuracy: 0.8120 - val_loss: 0.4107 - val_accuracy: 0.81742 - accuracy: 0.84
# 2023-05-07 17:08:48.900 [34/model/183 (pid 31593)] Epoch 4/20
# 566/566 [==============================] - 0s 752us/step - loss: 0.3802 - accuracy: 0.8342 - val_loss: 0.4205 - val_accuracy: 0.81417 - accuracy: 0.90
# 2023-05-07 17:08:54.935 [34/model/183 (pid 31593)] Epoch 18/20
# 566/566 [==============================] - 0s 788us/step - loss: 0.3806 - accuracy: 0.8341 - val_loss: 0.4192 - val_accuracy: 0.81198 - accuracy: 0.81
# 2023-05-07 17:08:55.382 [34/model/183 (pid 31593)] Epoch 19/20
# 566/566 [==============================] - 0s 756us/step - loss: 0.3845 - accuracy: 0.8352 - val_loss: 0.4216 - val_accuracy: 0.81560 - accuracy: 0.93
# 2023-05-07 17:08:55.810 [34/model/183 (pid 31593)] Epoch 20/20
# 566/566 [==============================] - 0s 812us/step - loss: 0.3848 - accuracy: 0.8318 - val_loss: 0.4223 - val_accuracy: 0.81395 - accuracy: 0.78
# 2023-05-07 17:08:56.365 [34/model/183 (pid 31593)] (4529,)
# 2023-05-07 17:08:56.612 [34/model/183 (pid 31593)] Pretty and comfortable fun cardi for those of us who love a nice little cropped number. glad to report that this cobalt beauty fits true to size in an xs all over -- shoulders hit at a nice place, arms, waist, length is great above your waist or just at it. the cotton is ultra comfortable. the zipper has that luxurious feature of a double zip where you can zip from the bottom or the top once closed, creating a nice opening. i love this for a casual but chic holiday look thanks to the velvet ador
# 2023-05-07 17:08:56.612 [34/model/183 (pid 31593)] (4529,)
# 2023-05-07 17:08:56.825 [34/model/183 (pid 31593)] Pretty and comfortable fun cardi for those of us who love a nice little cropped number. glad to report that this cobalt beauty fits true to size in an xs all over -- shoulders hit at a nice place, arms, waist, length is great above your waist or just at it. the cotton is ultra comfortable. the zipper has that luxurious feature of a double zip where you can zip from the bottom or the top once closed, creating a nice opening. i love this for a casual but chic holiday look thanks to the velvet ador
# 2023-05-07 17:08:56.825 [34/model/183 (pid 31593)] ** here
# 2023-05-07 17:08:56.841 [34/model/183 (pid 31593)] vocab_sz: 300
# 2023-05-07 17:08:56.842 [34/model/183 (pid 31593)] epochs: 20
# 2023-05-07 17:08:56.842 [34/model/183 (pid 31593)] batch_size: 32
# 2023-05-07 17:08:56.842 [34/model/183 (pid 31593)] (22641,)
# 2023-05-07 17:08:57.711 [34/model/183 (pid 31593)] Absolutely wonderful - silky and sexy and comfortable
# 2023-05-07 17:08:57.712 [34/model/183 (pid 31593)] Epoch 1/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.4774 - accuracy: 0.7711 - val_loss: 0.3555 - val_accuracy: 0.8505.7306 - accuracy: 0.50
# 2023-05-07 17:08:58.513 [34/model/183 (pid 31593)] Epoch 2/20
# 566/566 [==============================] - 0s 879us/step - loss: 0.3512 - accuracy: 0.8506 - val_loss: 0.3548 - val_accuracy: 0.85584 - accuracy: 0.90
# 2023-05-07 17:08:59.012 [34/model/183 (pid 31593)] Epoch 3/20
# 566/566 [==============================] - 0s 864us/step - loss: 0.3476 - accuracy: 0.8519 - val_loss: 0.3510 - val_accuracy: 0.85100 - accuracy: 0.90
# 2023-05-07 17:08:59.501 [34/model/183 (pid 31593)] Epoch 4/20
# 566/566 [==============================] - 0s 856us/step - loss: 0.3325 - accuracy: 0.8608 - val_loss: 0.3485 - val_accuracy: 0.85297 - accuracy: 0.81
# 2023-05-07 17:09:06.276 [34/model/183 (pid 31593)] Epoch 18/20
# 566/566 [==============================] - 0s 835us/step - loss: 0.2711 - accuracy: 0.8997 - val_loss: 0.3976 - val_accuracy: 0.84416 - accuracy: 0.93
# 2023-05-07 17:09:06.750 [34/model/183 (pid 31593)] Epoch 19/20
# 566/566 [==============================] - 0s 850us/step - loss: 0.2805 - accuracy: 0.8920 - val_loss: 0.4089 - val_accuracy: 0.83862 - accuracy: 0.90
# 2023-05-07 17:09:07.232 [34/model/183 (pid 31593)] Epoch 20/20
# 566/566 [==============================] - 0s 865us/step - loss: 0.2656 - accuracy: 0.9006 - val_loss: 0.4069 - val_accuracy: 0.83823 - accuracy: 0.96
# 2023-05-07 17:09:07.726 [34/model/183 (pid 31593)] (4529,)
# 2023-05-07 17:09:07.970 [34/model/183 (pid 31593)] Pretty and comfortable fun cardi for those of us who love a nice little cropped number. glad to report that this cobalt beauty fits true to size in an xs all over -- shoulders hit at a nice place, arms, waist, length is great above your waist or just at it. the cotton is ultra comfortable. the zipper has that luxurious feature of a double zip where you can zip from the bottom or the top once closed, creating a nice opening. i love this for a casual but chic holiday look thanks to the velvet ador
# 2023-05-07 17:09:07.971 [34/model/183 (pid 31593)] (4529,)
# 2023-05-07 17:09:08.193 [34/model/183 (pid 31593)] Pretty and comfortable fun cardi for those of us who love a nice little cropped number. glad to report that this cobalt beauty fits true to size in an xs all over -- shoulders hit at a nice place, arms, waist, length is great above your waist or just at it. the cotton is ultra comfortable. the zipper has that luxurious feature of a double zip where you can zip from the bottom or the top once closed, creating a nice opening. i love this for a casual but chic holiday look thanks to the velvet ador
# 2023-05-07 17:09:08.193 [34/model/183 (pid 31593)] ** here
# 2023-05-07 17:09:08.209 [34/model/183 (pid 31593)] vocab_sz: 500
# 2023-05-07 17:09:08.210 [34/model/183 (pid 31593)] epochs: 20
# 2023-05-07 17:09:08.210 [34/model/183 (pid 31593)] batch_size: 32
# 2023-05-07 17:09:08.210 [34/model/183 (pid 31593)] (22641,)
# 2023-05-07 17:09:09.166 [34/model/183 (pid 31593)] Absolutely wonderful - silky and sexy and comfortable
# 2023-05-07 17:09:09.167 [34/model/183 (pid 31593)] Epoch 1/20
# 566/566 [==============================] - 1s 1ms/step - loss: 0.4347 - accuracy: 0.8050 - val_loss: 0.3402 - val_accuracy: 0.8549.7092 - accuracy: 0.53
# 2023-05-07 17:09:10.025 [34/model/183 (pid 31593)] Epoch 2/20
# 566/566 [==============================] - 1s 971us/step - loss: 0.3295 - accuracy: 0.8618 - val_loss: 0.3353 - val_accuracy: 0.85742 - accuracy: 0.93
# 2023-05-07 17:09:10.576 [34/model/183 (pid 31593)] Epoch 3/20
# 566/566 [==============================] - 1s 943us/step - loss: 0.3142 - accuracy: 0.8693 - val_loss: 0.3370 - val_accuracy: 0.85742 - accuracy: 0.81
# 2023-05-07 17:09:11.111 [34/model/183 (pid 31593)] Epoch 4/20
# 566/566 [==============================] - 1s 935us/step - loss: 0.3138 - accuracy: 0.8654 - val_loss: 0.3375 - val_accuracy: 0.86163 - accuracy: 0.84
# 2023-05-07 17:09:18.653 [34/model/183 (pid 31593)] Epoch 18/20
# 566/566 [==============================] - 1s 973us/step - loss: 0.2293 - accuracy: 0.9195 - val_loss: 0.4204 - val_accuracy: 0.84927 - accuracy: 0.78
# 2023-05-07 17:09:19.204 [34/model/183 (pid 31593)] Epoch 19/20
# 566/566 [==============================] - 1s 948us/step - loss: 0.2349 - accuracy: 0.9164 - val_loss: 0.4233 - val_accuracy: 0.84763 - accuracy: 0.96
# 2023-05-07 17:09:19.742 [34/model/183 (pid 31593)] Epoch 20/20
# 566/566 [==============================] - 1s 957us/step - loss: 0.2277 - accuracy: 0.9218 - val_loss: 0.4263 - val_accuracy: 0.84430 - accuracy: 0.96
# 2023-05-07 17:09:20.290 [34/model/183 (pid 31593)] (4529,)
# 2023-05-07 17:09:20.546 [34/model/183 (pid 31593)] Pretty and comfortable fun cardi for those of us who love a nice little cropped number. glad to report that this cobalt beauty fits true to size in an xs all over -- shoulders hit at a nice place, arms, waist, length is great above your waist or just at it. the cotton is ultra comfortable. the zipper has that luxurious feature of a double zip where you can zip from the bottom or the top once closed, creating a nice opening. i love this for a casual but chic holiday look thanks to the velvet ador
# 2023-05-07 17:09:20.546 [34/model/183 (pid 31593)] (4529,)
# 2023-05-07 17:09:24.035 [34/model/183 (pid 31593)] 2023-05-07 17:08:46.788975: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# 2023-05-07 17:09:24.035 [34/model/183 (pid 31593)] Pretty and comfortable fun cardi for those of us who love a nice little cropped number. glad to report that this cobalt beauty fits true to size in an xs all over -- shoulders hit at a nice place, arms, waist, length is great above your waist or just at it. the cotton is ultra comfortable. the zipper has that luxurious feature of a double zip where you can zip from the bottom or the top once closed, creating a nice opening. i love this for a casual but chic holiday look thanks to the velvet ador
# 2023-05-07 17:09:24.281 [34/model/183 (pid 31593)] Task finished successfully.
# 2023-05-07 17:09:24.590 [34/aggregate/184 (pid 32034)] Task is starting.
# 2023-05-07 17:09:27.609 [34/aggregate/184 (pid 32034)] ModelResult(name='Baseline', params='Always predict 1', pathspec='BaselineChallenge_01/34/baseline/182', acc=0.7677191432987415, rocauc=0.5)
# 2023-05-07 17:09:27.662 [34/aggregate/184 (pid 32034)] ModelResult(name='NbowModel - vocab_sz: 100', params={'vocab_sz': 100, 'epochs': 20, 'batch_size': 32}, pathspec='BaselineChallenge_01/34/model/183', acc=0.8381541179068227, rocauc=0.8672665347842585)
# 2023-05-07 17:09:27.663 [34/aggregate/184 (pid 32034)] ModelResult(name='NbowModel - vocab_sz: 300', params={'vocab_sz': 300, 'epochs': 20, 'batch_size': 32}, pathspec='BaselineChallenge_01/34/model/183', acc=0.8997571207772135, rocauc=0.9479067221753816)
# 2023-05-07 17:09:30.424 [34/aggregate/184 (pid 32034)] ModelResult(name='NbowModel - vocab_sz: 500', params={'vocab_sz': 500, 'epochs': 20, 'batch_size': 32}, pathspec='BaselineChallenge_01/34/model/183', acc=0.9286818282181497, rocauc=0.9656843286299648)
# 2023-05-07 17:09:30.600 [34/aggregate/184 (pid 32034)] Task finished successfully.
# 2023-05-07 17:09:30.876 [34/end/185 (pid 32138)] Task is starting.
# 2023-05-07 17:09:33.354 [34/end/185 (pid 32138)] Task finished successfully.
# 2023-05-07 17:09:33.469 Done! See the run in the UI at https://ui-pw-1998985377.outerbounds.dev/BaselineChallenge_01/34
